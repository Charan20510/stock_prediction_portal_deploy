# %%
import numpy as np

# %%
arr = np.array([[[1, 2, 3], [5, 1, 4]], [[3, 8, 2],[9, 4, 6]], [[7, 5, 9], [3, 1, 8]]])
arr
# Out:
# array([[[1, 2, 3],
#         [5, 1, 4]],
#
#        [[3, 8, 2],
#         [9, 4, 6]],
#
#        [[7, 5, 9],
#         [3, 1, 8]]])

# %%
arr.shape
# Out:
# (3, 2, 3)

# %%
arr[0, 0, 2]
# Out:
# np.int64(3)

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 6, 2, 9, 7]
y = [10, 20, 30, 40, 50]

# %%
plt.plot(x, y);
plt.title('line graph');
plt.ylabel('y-axis');
